# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Cleaning RansomHub Data

# %%
df = pd.read_csv('CSV_files/RansomHub.csv')
df.loc[-1] = ['2024-09-29', 'markdom.com', 'RansomHub']
df.index = df.index + 1
df.sort_index(inplace=True)
df.columns = ['Date', 'Victim', 'Ransomware Group']
df.insert(2, "Country", "")

# %%
import ollama
index = 0
for victim in df['Victim']:
    response = ollama.chat(model='llama3', messages=[
        {
            'role': 'user',
            'content': f'I am going to give you the website of a victim of ransomware. I need you to provide me with the country the company is based in. Nothing else. Just the country. No other information. Give only the sountry as your response. The victim site is {victim}',

        },
    ])

    country = (response['message']['content'])
    print(country)

    rowIndex = df.index[index]
    df.loc[rowIndex, 'Country'] = country
    
    index += 1
# Out:
# USA
# United States
# United States
# United States
# Japan
# Brazil
# Sweden
# Japan
# Poland
# Brazil
# United States
# Canada
# Turkey
# Turkey
# Brazil
# Peru
# United States
# Spain
# United States
# United States
# Australia
# Poland
# United States
# United States
# Australia
# United States
# United States
# Australia
# United States
# United States
# United States
# Italy
# United States
# United States
# United States
# United States
# United States
# United States
# USA
# Australia
# United States
# United States
# India
# Italy
# Lithuania
# United States
# Germany
# United States
# United States
# United Kingdom
# United States
# Germany
# United States
# Canada
# United Kingdom
# New Zealand
# United States
# United States
# United States
# Italy
# Japan
# South Africa
# United States
# Taiwan
# United Kingdom
# Switzerland
# Canada
# United Arab Emirates (UAE)
# United Kingdom
# United States
# Switzerland
# United States
# United States
# France
# South Africa
# ...

# %%
df['Country'].replace('USA', 'United States', inplace=True)
df['Country'].replace('UK', 'United Kingdom', inplace=True)
df['Date'] = pd.to_datetime(df['Date'], format="%Y %m %d")

# %%
df.to_csv('RansomHub_Cleaned.csv')

# %% [markdown]
# # Cleaning LockBit3.0 Data

# %%
df = pd.read_csv('CSV_files/LockBit3.0_new.csv')
df.loc[-1] = ['04 Oct 2024', 'kumhotire.com', 'LockBit3.0']
df.index = df.index + 1
df.sort_index(inplace=True)
df.columns = ['Date', 'Victim', 'Ransomware Group']
df.insert(2, "Country", "")

# %%
import ollama
index = 0
for victim in df['Victim']:
    response = ollama.chat(model='llama3', messages=[
        {
            'role': 'user',
            'content': f'I am going to give you the website of a victim of ransomware. I need you to provide me with the country the company is based in. Nothing else. Just the country. No other information. Give only the sountry as your response. The victim site is {victim}',

        },
    ])

    country = (response['message']['content'])
    print(country)

    rowIndex = df.index[index]
    df.loc[rowIndex, 'Country'] = country
    
    index += 1
# Out:
# United States
# Australia
# Mexico
# United States
# Colombia
# United Kingdom
# Turkey
# United States
# United States
# Cyprus
# United States
# United States
# United States
# Brazil
# Mexico
# United States
# United States
# United States
# Brazil
# United States
# United States
# Afghanistan
# Italy
# United States
# Spain
# United Kingdom
# Australia
# United States
# Australia
# Australia
# United States
# United States
# United States
# United States
# United States
# Indonesia
# Canada
# Venezuela
# Mexico
# United States
# Japan
# Australia
# Japan
# Israel
# United States
# United States
# India
# United Kingdom
# Israel
# Namibia
# India
# Colombia
# Luxembourg
# United States
# United States
# Germany
# India
# United States
# Germany
# Indonesia
# Mexico
# Poland
# United Arab Emirates
# Vietnam
# India
# India
# Italy
# Argentina
# Thailand
# United Kingdom
# United States
# Spain
# Brazil
# Mexico
# United Kingdom
# Japan
# United States
# France
# United States
# ...

# %%
df.head()
# Out:
#           Date              Victim        Country Ransomware Group
# 0  04 Oct 2024       kumhotire.com  United States       LockBit3.0
# 1  03 Oct 2024  tpgagedcare.com.au      Australia       LockBit3.0
# 2  30 Sep 2024    oleopalma.com.mx         Mexico       LockBit3.0
# 3  30 Sep 2024             chcm.us  United States       LockBit3.0
# 4  26 Sep 2024         nhbg.com.co       Colombia       LockBit3.0

# %%
df['Country'].replace('USA', 'United States', inplace=True)
df['Country'].replace('UK', 'United Kingdom', inplace=True)

# %%
df.to_csv('LockBit3.0_Cleaned.csv')

# %% [markdown]
# # Cleaning PLAY Data

# %%
df = pd.read_csv('CSV_files/PLAY.csv')
df.loc[-1] = ['2024-09-23', 'wwweurobulkgr', 'Greece', 'PLAY']
df.index = df.index + 1
df.sort_index(inplace=True)
df.columns = ['Date', 'Victim', 'Country', 'Ransomware Group']
df['Date'] = pd.to_datetime(df['Date'], format="%Y %m %d")

# %%
df.to_csv('PLAY_Cleaned.csv')

# %% [markdown]
# # Distribution of Countries Targetted by Group

# %%
rh = pd.read_csv('CSV_files/Final_Distribution_Files/RansomHub_Cleaned.csv')
percentages = rh['Country'].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
countries = pd.DataFrame(rh['Country'])
countries = countries.drop_duplicates()
countries = countries.reset_index(drop=True)
countries.insert(1, column='Percent', value=0)

for i in range(len(countries)):
    country = countries['Country'][i]
    percent = percentages[country]
    countries['Percent'].iloc[i] = f'{percent}'

countries.to_csv("RansomHub_Countries.csv")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
lb = pd.read_csv('CSV_files/Final_Distribution_Files/LockBit3.0_Cleaned.csv')
percentages = lb['Country'].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
countries = pd.DataFrame(lb['Country'])
countries = countries.drop_duplicates()
countries = countries.reset_index(drop=True)
countries.insert(1, column='Percent', value=0)

for i in range(len(countries)):
    country = countries['Country'][i]
    percent = percentages[country]
    countries['Percent'].iloc[i] = f'{percent}'

countries.to_csv("LockBit3.0_Countries.csv")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
pl = pd.read_csv('CSV_files/Final_Distribution_Files/PLAY_Cleaned.csv')
percentages = pl['Country'].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
countries = pd.DataFrame(pl['Country'])
countries = countries.drop_duplicates()
countries = countries.reset_index(drop=True)
countries.insert(1, column='Percent', value=0)

for i in range(len(countries)):
    country = countries['Country'][i]
    percent = percentages[country]
    countries['Percent'].iloc[i] = f'{percent}'

countries.to_csv("PLAY_Countries.csv")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %% [markdown]
# # Merging all Groups

# %%
merged = pd.concat(map(pd.read_csv, ['CSV_files/Final_Distribution_Files/PLAY_Cleaned.csv', 'CSV_files/Final_Distribution_Files/RansomHub_cleaned.csv', 'CSV_files/Final_Distribution_Files/LockBit3.0_Cleaned.csv']), ignore_index=True)
merged = merged.drop(columns='Unnamed: 0')
merged.to_csv('Merged.csv')

# %%
m = pd.read_csv('CSV_files/Final_Distribution_Files/merged.csv')
percentages = m['Country'].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
countries = pd.DataFrame(m['Country'])
countries = countries.drop_duplicates()
countries = countries.reset_index(drop=True)
countries.insert(1, column='Percent', value=0)

for i in range(len(countries)):
    country = countries['Country'][i]
    percent = percentages[country]
    countries['Percent'].iloc[i] = f'{percent}'

countries.to_csv("Merged_Countries.csv")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
