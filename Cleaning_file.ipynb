# %%
import pandas as pd

# %% [markdown]
# # Cleaning RansomHub Data

# %%
df = pd.read_csv('CSV_files/RansomHub.csv')
df.loc[-1] = ['2024-09-29', 'markdom.com', 'RansomHub']
df.index = df.index + 1
df.sort_index(inplace=True)
df.columns = ['Date', 'Victim', 'Ransomware Group']
df.insert(2, "Country", "")

# %%
import ollama
index = 0
for victim in df['Victim']:
    response = ollama.chat(model='llama3', messages=[
        {
            'role': 'user',
            'content': f'I am going to give you the website of a victim of ransomware. I need you to provide me with the country the company is based in. Nothing else. Just the country. No other information. Give only the sountry as your response. The victim site is {victim}',

        },
    ])

    country = (response['message']['content'])
    print(country)

    rowIndex = df.index[index]
    df.loc[rowIndex, 'Country'] = country
    
    index += 1
# Out:
# USA
# United States
# United States
# United States
# Japan
# Brazil
# Sweden
# Japan
# Poland
# Brazil
# United States
# Canada
# Turkey
# Turkey
# Brazil
# Peru
# United States
# Spain
# United States
# United States
# Australia
# Poland
# United States
# United States
# Australia
# United States
# United States
# Australia
# United States
# United States
# United States
# Italy
# United States
# United States
# United States
# United States
# United States
# United States
# USA
# Australia
# United States
# United States
# India
# Italy
# Lithuania
# United States
# Germany
# United States
# United States
# United Kingdom
# United States
# Germany
# United States
# Canada
# United Kingdom
# New Zealand
# United States
# United States
# United States
# Italy
# Japan
# South Africa
# United States
# Taiwan
# United Kingdom
# Switzerland
# Canada
# United Arab Emirates (UAE)
# United Kingdom
# United States
# Switzerland
# United States
# United States
# France
# South Africa
# ...

# %%
df['Country'].replace('USA', 'United States', inplace=True)
df['Country'].replace('UK', 'United Kingdom', inplace=True)
df['Date'] = pd.to_datetime(df['Date'], format="%Y %m %d")

# %%
df.to_csv('RansomHub_Cleaned.csv')

# %% [markdown]
# # Cleaning LockBit3.0 Data

# %%
df = pd.read_csv('CSV_files/LockBit3.0_new.csv')
df.loc[-1] = ['04 Oct 2024', 'kumhotire.com', 'LockBit3.0']
df.index = df.index + 1
df.sort_index(inplace=True)
df.columns = ['Date', 'Victim', 'Ransomware Group']
df.insert(2, "Country", "")

# %%
import ollama
index = 0
for victim in df['Victim']:
    response = ollama.chat(model='llama3', messages=[
        {
            'role': 'user',
            'content': f'I am going to give you the website of a victim of ransomware. I need you to provide me with the country the company is based in. Nothing else. Just the country. No other information. Give only the sountry as your response. The victim site is {victim}',

        },
    ])

    country = (response['message']['content'])
    print(country)

    rowIndex = df.index[index]
    df.loc[rowIndex, 'Country'] = country
    
    index += 1
# Out:
# United States
# Australia
# Mexico
# United States
# Colombia
# United Kingdom
# Turkey
# United States
# United States
# Cyprus
# United States
# United States
# United States
# Brazil
# Mexico
# United States
# United States
# United States
# Brazil
# United States
# United States
# Afghanistan
# Italy
# United States
# Spain
# United Kingdom
# Australia
# United States
# Australia
# Australia
# United States
# United States
# United States
# United States
# United States
# Indonesia
# Canada
# Venezuela
# Mexico
# United States
# Japan
# Australia
# Japan
# Israel
# United States
# United States
# India
# United Kingdom
# Israel
# Namibia
# India
# Colombia
# Luxembourg
# United States
# United States
# Germany
# India
# United States
# Germany
# Indonesia
# Mexico
# Poland
# United Arab Emirates
# Vietnam
# India
# India
# Italy
# Argentina
# Thailand
# United Kingdom
# United States
# Spain
# Brazil
# Mexico
# United Kingdom
# Japan
# United States
# France
# United States
# ...

# %%
df.head()
# Out:
#           Date              Victim        Country Ransomware Group
# 0  04 Oct 2024       kumhotire.com  United States       LockBit3.0
# 1  03 Oct 2024  tpgagedcare.com.au      Australia       LockBit3.0
# 2  30 Sep 2024    oleopalma.com.mx         Mexico       LockBit3.0
# 3  30 Sep 2024             chcm.us  United States       LockBit3.0
# 4  26 Sep 2024         nhbg.com.co       Colombia       LockBit3.0

# %%
df['Country'].replace('USA', 'United States', inplace=True)
df['Country'].replace('UK', 'United Kingdom', inplace=True)

# %%
df.to_csv('LockBit3.0_Cleaned.csv')

# %% [markdown]
# # Cleaning PLAY Data

# %%
df = pd.read_csv('CSV_files/PLAY.csv')
df.loc[-1] = ['2024-09-23', 'wwweurobulkgr', 'Greece', 'PLAY']
df.index = df.index + 1
df.sort_index(inplace=True)
df.columns = ['Date', 'Victim', 'Country', 'Ransomware Group']
df['Date'] = pd.to_datetime(df['Date'], format="%Y %m %d")

# %%
df.to_csv('PLAY_Cleaned.csv')

# %% [markdown]
# # Distribution of Countries Targetted by Group

# %% [markdown]
# ## Countries Targetted by RansomHub

# %%
rh = pd.read_csv('CSV_files/Countries/RansomHub_Cleaned.csv')
percentages = rh['Country'].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
countries = pd.DataFrame(rh['Country'])
countries = countries.drop_duplicates()
countries = countries.reset_index(drop=True)
countries.insert(1, column='Percent', value=0)

for i in range(len(countries)):
    country = countries['Country'][i]
    percent = percentages[country]
    countries['Percent'].iloc[i] = f'{percent}'

countries.to_csv("RansomHub_Countries.csv")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %% [markdown]
# ## Countries Targetted by LockBit3.0

# %%
lb = pd.read_csv('CSV_files/Countries/LockBit3.0_Cleaned.csv')
percentages = lb['Country'].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
countries = pd.DataFrame(lb['Country'])
countries = countries.drop_duplicates()
countries = countries.reset_index(drop=True)
countries.insert(1, column='Percent', value=0)

for i in range(len(countries)):
    country = countries['Country'][i]
    percent = percentages[country]
    countries['Percent'].iloc[i] = f'{percent}'

countries.to_csv("LockBit3.0_Countries.csv")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %% [markdown]
# ## Countries Targetted by PLAY

# %%
pl = pd.read_csv('CSV_files/Countries/PLAY_Cleaned.csv')
percentages = pl['Country'].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
countries = pd.DataFrame(pl['Country'])
countries = countries.drop_duplicates()
countries = countries.reset_index(drop=True)
countries.insert(1, column='Percent', value=0)

for i in range(len(countries)):
    country = countries['Country'][i]
    percent = percentages[country]
    countries['Percent'].iloc[i] = f'{percent}'

countries.to_csv("PLAY_Countries.csv")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %% [markdown]
# # Merging all Groups

# %%
merged = pd.concat(map(pd.read_csv, ['CSV_files/Countries/PLAY_Cleaned.csv', 'CSV_files/Countries/RansomHub_cleaned.csv', 'CSV_files/Countries/LockBit3.0_Cleaned.csv']), ignore_index=True)
merged = merged.drop(columns='Unnamed: 0')
merged.to_csv('Merged.csv')

# %%
m = pd.read_csv('CSV_files/Countries/merged.csv')
percentages = m['Country'].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
countries = pd.DataFrame(m['Country'])
countries = countries.drop_duplicates()
countries = countries.reset_index(drop=True)
countries.insert(1, column='Percent', value=0)

for i in range(len(countries)):
    country = countries['Country'][i]
    percent = percentages[country]
    countries['Percent'].iloc[i] = f'{percent}'

countries.to_csv("Merged_Countries.csv")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %% [markdown]
# # Appending Targetted Industry Data

# %% [markdown]
# ## RansomHub

# %%
df = pd.read_csv('CSV_files/RansomHub_Cleaned.csv')
df.insert(3, column='Industry', value="")

import ollama
index = 0
for victim in df['Victim']:
    response = ollama.chat(model='llama3', messages=[
        {
            'role': 'user',
            'content': f'I am going to give you the website of a victim of ransomware. I need you to provide me with the industry the company is based in. Nothing else. Just the industry. No other information. Give only the industry as your response. The victim site is {victim}',

        },
    ])

    industry = (response['message']['content'])
    print(industry)

    rowIndex = df.index[index]
    df.loc[rowIndex, 'Industry'] = industry
    
    index += 1

print("Done")
# Out:
# Construction
# Healthcare
# Information Technology (IT) Services
# Oil and Gas
# Manufacturing
# Logistics
# Healthcare
# Healthcare
# Legal/Professional Services
# Energy and Utilities
# Government
# Energy
# Food and Beverage
# Food and Beverage
# Media
# Healthcare
# Real Estate
# Healthcare
# Financial Services
# Healthcare
# Energy
# Healthcare
# Healthcare
# Healthcare
# Logistics
# Banking
# Logistics/Transportation
# Manufacturing
# Wholesaling/retailing
# Education
# Healthcare
# Food/Beverage
# Healthcare
# Railroad
# Healthcare
# Healthcare
# Manufacturing
# Engineering/Construction
# Manufacturing
# Food Processing
# Graphics/Printing
# Medical Equipment
# Education
# Education
# Retail
# Telecommunications
# Consulting/Professional Services
# Logistics
# Education
# Construction
# Healthcare
# Automotive
# Engineering
# Transportation
# Hospitality
# Accounting
# Healthcare
# Real Estate
# Education
# Gaming/Entertainment
# Construction
# Beverage manufacturing
# ...

# %%
df.to_csv('CSV_files/Industries/RansomHub_Industries.csv')

# %% [markdown]
# ## Lockbit3.0

# %%
df = pd.read_csv('CSV_files/LockBit3.0_Cleaned.csv')
df.insert(3, column='Industry', value="")

import ollama
index = 0
for victim in df['Victim']:
    response = ollama.chat(model='llama3', messages=[
        {
            'role': 'user',
            'content': f'I am going to give you the website of a victim of ransomware. I need you to provide me with the industry the company is based in. Nothing else. Just the industry. No other information. Give only the industry as your response. The victim site is {victim}',

        },
    ])

    industry = (response['message']['content'])
    print(industry)

    rowIndex = df.index[index]
    df.loc[rowIndex, 'Industry'] = industry
    
    index += 1

print("Done")
# Out:
# Transportation
# Healthcare
# Food and Beverage
# Healthcare
# Banking
# Construction
# Finance
# Payment Processing
# Tax preparation
# E-commerce
# Chamber/Association
# Consumer Goods
# Healthcare
# Healthcare
# Healthcare
# Education
# Education
# Manufacturing
# Agriculture
# Automotive
# Funeral Services
# Healthcare
# Healthcare
# Education
# Healthcare
# E-commerce
# Design and Construction
# Construction
# Healthcare
# Professional Services
# Finance
# Logistics
# Healthcare
# Automotive
# Banking
# Agriculture
# Education
# Agriculture
# Energy
# Construction
# Healthcare
# Logistics/Transportation
# Education
# Healthcare
# Research and Consulting
# Agricultural Equipment
# Entertainment
# Interior Design/Furniture
# Financial Services
# Education
# Engineering/Consulting
# Sports Equipment
# Agriculture
# Law Firms
# Fraternity/Sorority
# Law Firm/Justice
# Healthcare
# Energy
# Logistics
# Manufacturing
# Healthcare
# Healthcare
# Construction
# Government
# ...

# %%
df.to_csv('CSV_files/Industries/LockBit3.0_Industries.csv')

# %% [markdown]
# ## PLAY

# %%
df = pd.read_csv('CSV_files/PLAY_Cleaned.csv')
df.insert(3, column='Industry', value="")

import ollama
index = 0
for victim in df['Victim']:
    response = ollama.chat(model='llama3', messages=[
        {
            'role': 'user',
            'content': f'I am going to give you the website of a victim of ransomware. I need you to provide me with the industry the company is based in. Nothing else. Just the industry. No other information. Give only the industry as your response. The victim site is {victim}',

        },
    ])

    industry = (response['message']['content'])
    print(industry)

    rowIndex = df.index[index]
    df.loc[rowIndex, 'Industry'] = industry
    
    index += 1

print("Done")
# Out:
# Maritime
# Agriculture
# Healthcare
# Transportation
# Oil and Gas
# Environmental Services
# Healthcare
# Healthcare
# Construction
# Healthcare
# Healthcare
# Charity/Non-profit
# Television
# Manufacturing
# Food Processing
# Finance
# Law Firm
# Semiconductor Manufacturing
# Lighting
# Healthcare
# Hospitality
# Advertising
# Financial Services
# Retail
# Business Services
# Rubber/Plastics Manufacturing
# Telecommunications
# Consulting
# Manufacturing
# Logistics
# Logistics
# Food and Beverage
# Construction/Contracting
# Marketing
# Mile High Companies appears to be in the **Logistics/Transportation** industry.
# Shipping/Logistics
# Agriculture
# Healthcare
# Logistics
# Manufacturing
# Environmental Services
# Healthcare
# Healthcare
# Manufacturing
# Healthcare
# Manufacturing
# Non-profit/Charity
# Manufacturing
# Healthcare
# Toys and Games
# Healthcare
# Non-profit/Charity
# Healthcare
# Electrical
# Hospitality
# Oil and Gas
# Government
# Healthcare
# ...

# %%
df.to_csv('CSV_files/Industries/PLAY_Industries.csv')

# %%
df = pd.read_csv('CSV_files/Industries/PLAY_Industries.csv')
df = df.drop(columns='Unnamed: 0')
df = df.drop(columns='Unnamed: 0.1')
df.to_csv('CSV_files/PLAY_Cleaned.csv')

# %%
df = pd.read_csv('CSV_files/Industries/LockBit3.0_Industries.csv')
df = df.drop(columns='Unnamed: 0')
df = df.drop(columns='Unnamed: 0.1')
df.to_csv('CSV_files/LockBit3.0_Cleaned.csv')

# %%
df = pd.read_csv('CSV_files/Industries/RansomHub_Industries.csv')
df = df.drop(columns='Unnamed: 0')
df = df.drop(columns='Unnamed: 0.1')
df.to_csv('CSV_files/RansomHub_Cleaned.csv')

# %% [markdown]
# # Seperating Industries Targetted by Each Group

# %% [markdown]
# ## Industries Targetted by RansomHub

# %%
rh = pd.read_csv('CSV_files/RansomHub_Cleaned.csv')
percentages = rh['Industry'].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
industries = pd.DataFrame(rh['Industry'])
industries = industries.drop_duplicates()
industries = industries.reset_index(drop=True)
industries.insert(1, column='Percent', value=0)

for i in range(len(industries)):
    industry = industries['Industry'][i]
    percent = percentages[industry]
    industries['Percent'].iloc[i] = f'{percent}'

industries.to_csv("CSV_files/Industries/RansomHub_Industries.csv")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %% [markdown]
# ## Industries Targetted by LockBit3.0

# %%
lb = pd.read_csv('CSV_files/LockBit3.0_Cleaned.csv')
percentages = lb['Industry'].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
industries = pd.DataFrame(lb['Industry'])
industries = industries.drop_duplicates()
industries = industries.reset_index(drop=True)
industries.insert(1, column='Percent', value=0)

for i in range(len(industries)):
    industry = industries['Industry'][i]
    percent = percentages[industry]
    industries['Percent'].iloc[i] = f'{percent}'

industries.to_csv("CSV_files/Industries/LockBit3.0_Industries.csv")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %% [markdown]
# ## Industries Targetted by PLAY

# %%
pl = pd.read_csv('CSV_files/PLAY_Cleaned.csv')
percentages = pl['Industry'].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
industries = pd.DataFrame(pl['Industry'])
industries = industries.drop_duplicates()
industries = industries.reset_index(drop=True)
industries.insert(1, column='Percent', value=0)

for i in range(len(industries)):
    industry = industries['Industry'][i]
    percent = percentages[industry]
    industries['Percent'].iloc[i] = f'{percent}'

industries.to_csv("CSV_files/Industries/PLAY_Industries.csv")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %% [markdown]
# # Merging all the Industries targetted by each group

# %%
merged = pd.concat(map(pd.read_csv, ['CSV_files/PLAY_Cleaned.csv', 'CSV_files/RansomHub_cleaned.csv', 'CSV_files/LockBit3.0_Cleaned.csv']), ignore_index=True)
merged = merged.drop(columns='Unnamed: 0')
merged.to_csv('CSV_files/Industries/Merged.csv')

# %%
m = pd.read_csv('CSV_files/Industries/Merged.csv')
percentages = m['Industry'].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
industries = pd.DataFrame(m['Industry'])
industries = industries.drop_duplicates()
industries = industries.reset_index(drop=True)
industries.insert(1, column='Percent', value=0)

for i in range(len(industries)):
    industry = industries['Industry'][i]
    percent = percentages[industry]
    industries['Percent'].iloc[i] = f'{percent}'

industries.to_csv("CSV_files/Industries/Merged_Industries.csv")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %% [markdown]
# # Finding Insights

# %%
merged = pd.concat(map(pd.read_csv, ['CSV_files/PLAY_Cleaned.csv', 'CSV_files/RansomHub_cleaned.csv', 'CSV_files/LockBit3.0_Cleaned.csv']), ignore_index=True)
merged.to_csv('CSV_files/Merged.csv')
merged = merged.drop(columns='Unnamed: 0')

# %%
merged = merged.sort_values(by='Date').reset_index().drop(columns='index')

# %%
USA = pd.DataFrame(merged[merged['Country'] == 'United States'])
USA.reset_index().drop(columns='index')

USA['Ransomware Group'].value_counts()
# Out:
# LockBit3.0    217
# PLAY          197
# RansomHub     103
# Name: Ransomware Group, dtype: int64

# %%
USA['Industry'].value_counts()
# Out:
# Healthcare                       126
# Manufacturing                     41
# Education                         25
# Construction                      21
# Logistics                         14
#                                 ...
# Health and Fitness                 1
# Software                           1
# Electric Power Generation          1
# Packaging/Logistics                1
# Rubber/Plastics Manufacturing      1
# Name: Industry, Length: 152, dtype: int64

# %%
UK = pd.DataFrame(merged[merged['Country'] == 'United Kingdom'])
UK.reset_index().drop(columns='index')
# Out:
#           Date                        Victim  \
# 0   2023-12-20              wwwjonrichardcom
# 1   2024-02-26                   stemcor.com
# 2   2024-02-26              gatesshields.com
# 3   2024-03-02                  wombleco.com
# 4   2024-03-02                  crbgroup.com
# 5   2024-03-11              wwwfashionsukcom
# 6   2024-03-16          newmans-online.co.uk
# 7   2024-03-31                worthenind.com
# 8   2024-04-15              jeyesfluid.co.uk
# 9   2024-04-25             www.jutebag.co.uk
# 10  2024-05-04           www.thaayakam.co.uk
# 11  2024-05-06                    eviivo.com
# 12  2024-05-09           equatortrustees.com
# 13  2024-05-09            themisbourne.co.uk
# 14  2024-05-21                   ramfoam.com
# 15  2024-05-26       www.christies.com<SOLD>
# 16  2024-06-02                   heras.co.uk
# 17  2024-06-23     wwwinquesttechnologiescom
# 18  2024-07-15           townandforest.co.uk
# 19  2024-07-26                    e21c.co.uk
# ...

# %%
UK['Ransomware Group'].value_counts()
# Out:
# LockBit3.0    25
# RansomHub     14
# PLAY           3
# Name: Ransomware Group, dtype: int64

# %%
UK['Industry'].value_counts()
# Out:
# Education                              7
# Manufacturing                          5
# Healthcare                             4
# Construction                           3
# Engineering                            3
# Hospitality                            2
# Consulting                             2
# Local Government/Community Services    1
# Energy                                 1
# Food and Beverage                      1
# Housing                                1
# Interior Design/Furniture              1
# Motor Sports                           1
# Oil and Gas                            1
# Utilities                              1
# Art and Antiques                       1
# Steel                                  1
# Financial Services                     1
# Textile/Apparel                        1
# Cybersecurity                          1
# Pharmaceutical                         1
# Fashion                                1
# E-commerce                             1
# ...

# %%
canada = pd.DataFrame(merged[merged['Country'] == 'Canada'])
canada.reset_index().drop(columns='index')
# Out:
#           Date                        Victim  \
# 0   2023-12-21                   wwwquiltyca
# 1   2024-03-01  wwwinfluencecommunicationcom
# 2   2024-03-01                wwwtransplusio
# 3   2024-03-01            wwwcompactmouldcom
# 4   2024-03-01              wwwkoolairinccom
# 5   2024-03-02                      pcli.com
# 6   2024-03-11                  wwwqigroupca
# 7   2024-03-11                      wwwzsbca
# 8   2024-03-18          pronatindustries.com
# 9   2024-03-21            northerncasket.com
# 10  2024-03-26                 npgandour.com
# 11  2024-04-05                 truehomes.com
# 12  2024-04-08            www.skywaycoach.ca
# 13  2024-04-11               wwwtheatrixxcom
# 14  2024-04-11                    wwwmbtwcom
# 15  2024-04-17                 craigwire.com
# 16  2024-05-06                 signiflow.com
# 17  2024-05-06                netspectrum.ca
# 18  2024-05-06                    cdev.gc.ca
# 19  2024-05-06           parat-techology.com
# ...

# %%
canada['Industry'].value_counts()
# Out:
# Healthcare                                           12
# Manufacturing                                         5
# Transportation                                        4
# Construction                                          2
# Financial Services                                    2
# Education                                             2
# Energy                                                2
# Retail                                                2
# Agriculture                                           2
# Banking                                               1
# Quality Assurance (QA)                                1
# Charity/Non-profit                                    1
# Non-profit/Charity                                    1
# HVAC (Heating, Ventilation, and Air Conditioning)     1
# Food Processing                                       1
# Aerospace                                             1
# Design/Architecture                                   1
# ...

# %%
canada['Ransomware Group'].value_counts()
# Out:
# PLAY          24
# LockBit3.0    22
# RansomHub      8
# Name: Ransomware Group, dtype: int64

# %%
jan = pd.DataFrame(merged)

for i in range(len(jan)):
    if(not jan['Date'][i][5:7] == '01'):
        jan = jan.drop(index=i)

jan
# Out:
#          Date                 Victim      Industry        Country  \
# 7  2024-01-06        wwwteleverdecom    Healthcare  United States
# 8  2024-01-19  wwwtpgarchitecturecom  Architecture  United States
#
#   Ransomware Group
# 7             PLAY
# 8             PLAY

# %%
feb = pd.DataFrame(merged)

for i in range(len(feb)):
    if(not feb['Date'][i][5:7] == '02'):
        feb = feb.drop(index=i)

feb
# Out:
#           Date                     Victim                    Industry  \
# 9   2024-02-05                  wwwdclorg          Defense Contractor
# 10  2024-02-05      wwwleadersstaffingcom         Staffing/Recruiting
# 11  2024-02-05                  wwwdclorg         Defense Contracting
# 12  2024-02-05      wwwleadersstaffingcom                 Staffing/HR
# 13  2024-02-07             www.ykp.com.br              Transportation
# 14  2024-02-15          wwwmeerservicesnl           Maritime/Shipping
# 15  2024-02-15             wwwmechrepscom               Manufacturing
# 16  2024-02-15           wwwnorfoxchemcom                   Chemicals
# 17  2024-02-15             wwwvonhagennet                 Agriculture
# 18  2024-02-15              wwwlddaviscom               Manufacturing
# 19  2024-02-15          wwwmeerservicesnl               Manufacturing
# 20  2024-02-15            wwwonclusivecom                  Healthcare
# ...

# %%
mar = pd.DataFrame(merged)

for i in range(len(mar)):
    if(not mar['Date'][i][5:7] == '03'):
        mar = mar.drop(index=i)

mar
# Out:
#            Date                        Victim                     Industry  \
# 42   2024-03-01            wwwskylandgraincom                  Agriculture
# 43   2024-03-01            wwwskylandgraincom                  Agriculture
# 44   2024-03-01              wwwcoastalcarcom                   Automotive
# 45   2024-03-01  wwwinfluencecommunicationcom               Communications
# 46   2024-03-01                wwwmarketoncom                   Healthcare
# ..          ...                           ...                          ...
# 158  2024-03-27         wwwlambdaenergyllccom                       Energy
# 159  2024-03-28                www.avantit.no  Information Technology (IT)
# 160  2024-03-29         eni.com&mellitahog.ly                       Energy
# 161  2024-03-31                worthenind.com                Manufacturing
# 162  2024-03-31                  sbmandco.com                Manufacturing
#
#             Country Ransomware Group
# ...

# %%
apr = pd.DataFrame(merged)

for i in range(len(apr)):
    if(not apr['Date'][i][5:7] == '04'):
        apr = apr.drop(index=i)

apr
# Out:
#            Date                   Victim                 Industry  \
# 163  2024-04-02  www.constelacion.com.sv                   Energy
# 164  2024-04-03      www.agenciahost.com  Web Development/Hosting
# 165  2024-04-04          wwwsitnsleepcom               Healthcare
# 166  2024-04-04          wwwguysfloorcom                 Retailer
# 167  2024-04-04          wwweverbritecom               Healthcare
# ..          ...                      ...                      ...
# 226  2024-04-30             wwwnetabncom       Telecommunications
# 227  2024-04-30              ottlite.com               Healthcare
# 228  2024-04-30             sbsofbak.com                  Banking
# 229  2024-04-30            wwwcanatalnet   Shipping and Logistics
# 230  2024-04-30    wwwprofileproductscom            Manufacturing
#
#            Country Ransomware Group
# 163    El Salvador        RansomHub
# 164         Brazil        RansomHub
# 165  United States             PLAY
# ...

# %%
may = pd.DataFrame(merged)

for i in range(len(may)):
    if(not may['Date'][i][5:7] == '05'):
        may = may.drop(index=i)

may
# Out:
#            Date                      Victim                  Industry  \
# 231  2024-05-02              www.extraco.ae  Logistics/Transportation
# 232  2024-05-03      wwwstainlessfoundrycom             Manufacturing
# 233  2024-05-04         www.thaayakam.co.uk                 Education
# 234  2024-05-05           www.kamojou.co.za             Manufacturing
# 235  2024-05-06               signiflow.com                 Logistics
# ..          ...                         ...                       ...
# 439  2024-05-29  www.clevo.com.tw<Disclose>         Computer Hardware
# 440  2024-05-30               wwwfplfoodcom           Food Processing
# 441  2024-05-30                    wwwntvca                Television
# 442  2024-05-30                wwwwalsercom             Manufacturing
# 443  2024-05-30           aytosanlorenzo.es                Automotive
#
#                   Country Ransomware Group
# 231  United Arab Emirates        RansomHub
# ...

# %%
jun = pd.DataFrame(merged)

for i in range(len(jun)):
    if(not jun['Date'][i][5:7] == '06'):
        jun = jun.drop(index=i)
jun
# Out:
#            Date                      Victim                       Industry  \
# 444  2024-06-01                  cfymca.org             Non-profit/Charity
# 445  2024-06-01  www.sicoob.com.br<Updated>                        Banking
# 446  2024-06-01                Frontier.com             Telecommunications
# 447  2024-06-02                 heras.co.uk                   Construction
# 448  2024-06-02      smithandcaugheys.co.nz  Lawyers/Professional Services
# ..          ...                         ...                            ...
# 500  2024-06-27             www.cipl.org.in                     Healthcare
# 501  2024-06-27        midamea.com<Auction>                       Auctions
# 502  2024-06-28                 Spandex.com                Apparel/Fashion
# 503  2024-06-29            www.hauptmann.at                     Healthcare
# 504  2024-06-29    www.finecopneumatica.com                    Oil and Gas
#
#             Country Ransomware Group
# ...

# %%
jul = pd.DataFrame(merged)

for i in range(len(jul)):
    if(not jul['Date'][i][5:7] == '07'):
        jul = jul.drop(index=i)

jul
# Out:
#            Date                   Victim             Industry        Country  \
# 505  2024-07-01        floridahealth.gov           Government  United States
# 506  2024-07-01         www.sfmedical.de           Healthcare        Germany
# 507  2024-07-01           www.nttdata.ro        IT/Technology        Romania
# 508  2024-07-02            www.zepter.de           Healthcare        Germany
# 509  2024-07-02   www.daesangamerica.com      Food Processing  United States
# ..          ...                      ...                  ...            ...
# 624  2024-07-30  verwarmingheyndrickx.be           Healthcare        Belgium
# 625  2024-07-31               qftemb.com           Healthcare  United States
# 626  2024-07-31                 wgma.org           Healthcare  United States
# 627  2024-07-31                 nydj.com           Healthcare  United States
# 628  2024-07-31   www.bahia-principe.com  Hospitality/Tourism         Mexico
#
#     Ransomware Group
# 505        RansomHub
# ...

# %%
aug = pd.DataFrame(merged)

for i in range(len(aug)):
    if(not aug['Date'][i][5:7] == '08'):
        aug = aug.drop(index=i)
aug
# Out:
#            Date                  Victim            Industry  \
# 629  2024-08-01             marvell.com       Semiconductor
# 630  2024-08-01           at-global.com           Logistics
# 631  2024-08-01       alliedtelesis.com  Telecommunications
# 632  2024-08-01  mcdowallaffleck.com.au      Legal Services
# 633  2024-08-01    effinghamschools.com           Education
# ..          ...                     ...                 ...
# 836  2024-08-30         www.iiitd.ac.in           Education
# 837  2024-08-30      www.mineduc.gob.gt           Education
# 838  2024-08-30       www.primariatm.ro          Healthcare
# 839  2024-08-30      fanningfanning.com           Education
# 840  2024-08-31    www.nissan-dubai.com          Automotive
#
#                         Country Ransomware Group
# 629               United States       LockBit3.0
# 630                     Germany       LockBit3.0
# 631                 New Zealand       LockBit3.0
# ...

# %% [markdown]
# ## August and May have the most number of attacks

# %%
aug['Industry'].value_counts()
# Out:
# Healthcare             49
# Education              22
# Manufacturing          11
# Construction           10
# Logistics               7
#                        ..
# Accounting/CPA Firm     1
# Building Materials      1
# Software/Technology     1
# Motor Sports            1
# Home Security           1
# Name: Industry, Length: 77, dtype: int64

# %%
may['Industry'].value_counts()
# Out:
# Healthcare                   50
# Education                    15
# Manufacturing                12
# Transportation                9
# Financial Services            8
#                              ..
# Legal Services                1
# Architecture/Construction     1
# Wood and wood products        1
# Agriculture                   1
# Television                    1
# Name: Industry, Length: 74, dtype: int64

# %%
aug['Ransomware Group'].value_counts()
# Out:
# LockBit3.0    116
# RansomHub      70
# PLAY           26
# Name: Ransomware Group, dtype: int64

# %%
may['Ransomware Group'].value_counts()
# Out:
# LockBit3.0    160
# PLAY           29
# RansomHub      24
# Name: Ransomware Group, dtype: int64

# %%
aug['Country'].value_counts()
# Out:
# United States                 97
# United Kingdom                17
# Australia                     12
# Canada                         9
# France                         7
# India                          6
# Japan                          4
# Sweden                         4
# South Africa                   4
# Brazil                         4
# Germany                        3
# Spain                          3
# Italy                          3
# Mexico                         3
# New Zealand                    3
# Ireland                        2
# Peru                           2
# Poland                         2
# Romania                        2
# Israel                         2
# Vietnam                        2
# Guatemala                      1
# Switzerland                    1
# Malaysia                       1
# Togo                           1
# Bangladesh                     1
# Indonesia                      1
# Venezuela                      1
# ...

# %%
may['Country'].value_counts()
# Out:
# United States           109
# Canada                   11
# Brazil                    9
# Spain                     8
# France                    8
# India                     8
# Germany                   6
# United Kingdom            6
# Russia                    5
# South Africa              4
# Italy                     4
# Poland                    3
# Chile                     2
# Australia                 2
# Argentina                 2
# Sweden                    2
# Japan                     2
# Thailand                  1
# Slovakia                  1
# Portugal                  1
# Trinidad and Tobago       1
# Turkey                    1
# China                     1
# Romania                   1
# Ukraine                   1
# Serbia                    1
# Czech Republic            1
# United Arab Emirates      1
# Vietnam                   1
# Mexico                    1
# Indonesia                 1
# Austria                   1
# Belgium                   1
# ...

# %%
merged[merged['Country'] == 'China']
# Out:
#            Date          Victim            Industry Country Ransomware Group
# 397  2024-05-16  sunwave.com.cn  Telecommunications   China       LockBit3.0
# 574  2024-07-22         kns.com          Healthcare   China       LockBit3.0
# 600  2024-07-26    jdbchina.com           Logistics   China       LockBit3.0
# 605  2024-07-26    atcdi.com.cn           Aerospace   China       LockBit3.0
# 744  2024-08-12    inouemfg.com       Manufacturing   China       LockBit3.0

# %%
merged[merged['Industry'] == 'Healthcare']
# Out:
#            Date                   Victim    Industry        Country  \
# 0    2023-12-18            wwwcmpaulacom  Healthcare  United States
# 4    2023-12-20         wwwconceptdatadk  Healthcare        Denmark
# 7    2024-01-06          wwwteleverdecom  Healthcare  United States
# 20   2024-02-15          wwwonclusivecom  Healthcare  United States
# 34   2024-02-26          apeagers.com.au  Healthcare      Australia
# ..          ...                      ...         ...            ...
# 955  2024-09-26   www.tokiwa-group.co.jp  Healthcare          Japan
# 956  2024-09-26            www.careco.se  Healthcare         Sweden
# 960  2024-09-28  rockymountaingastro.com  Healthcare  United States
# 974  2024-09-30                  chcm.us  Healthcare  United States
# 976  2024-10-03       tpgagedcare.com.au  Healthcare      Australia
#
#     Ransomware Group
# 0               PLAY
# 4               PLAY
# 7               PLAY
# 20              PLAY
# 34        LockBit3.0
# ...

# %%
jan['Country'].value_counts()
# Out:
# United States    2
# Name: Country, dtype: int64

# %%
feb['Country'].value_counts()
# Out:
# United States     20
# Brazil             2
# Netherlands        2
# Germany            2
# United Kingdom     2
# Australia          2
# Romania            1
# France             1
# Malaysia           1
# Name: Country, dtype: int64

# %%
mar['Country'].value_counts()
# Out:
# United States     64
# Germany           14
# Canada            10
# United Kingdom     5
# Australia          4
# Sweden             2
# Brazil             2
# Turkey             2
# Poland             2
# Malaysia           1
# Norway             1
# Namibia            1
# Wisconsin          1
# Spain              1
# Romania            1
# Egypt              1
# Slovakia           1
# Peru               1
# Korea              1
# Mexico             1
# Portugal           1
# Pakistan           1
# Greece             1
# Albania            1
# Italy              1
# Name: Country, dtype: int64

# %%
apr['Country'].value_counts()
# Out:
# United States     43
# Canada             5
# Australia          3
# Spain              3
# Italy              2
# United Kingdom     2
# El Salvador        1
# Brazil             1
# Colombia           1
# Nigeria            1
# Japan              1
# Netherlands        1
# Ireland            1
# Afghanistan        1
# Slovakia           1
# France             1
# Name: Country, dtype: int64

# %%
may['Country'].value_counts()
# Out:
# United States           109
# Canada                   11
# Brazil                    9
# Spain                     8
# France                    8
# India                     8
# Germany                   6
# United Kingdom            6
# Russia                    5
# South Africa              4
# Italy                     4
# Poland                    3
# Chile                     2
# Australia                 2
# Argentina                 2
# Sweden                    2
# Japan                     2
# Thailand                  1
# Slovakia                  1
# Portugal                  1
# Trinidad and Tobago       1
# Turkey                    1
# China                     1
# Romania                   1
# Ukraine                   1
# Serbia                    1
# Czech Republic            1
# United Arab Emirates      1
# Vietnam                   1
# Mexico                    1
# Indonesia                 1
# Austria                   1
# Belgium                   1
# ...

# %%
jun['Country'].value_counts()
# Out:
# United States     35
# Italy              6
# Canada             5
# Brazil             3
# United Kingdom     2
# New Zealand        1
# Netherlands        1
# Switzerland        1
# Argentina          1
# Sweden             1
# Spain              1
# Myanmar            1
# India              1
# Austria            1
# Romania            1
# Name: Country, dtype: int64

# %%
jul['Country'].value_counts()
# Out:
# United States     66
# Germany            8
# France             5
# Brazil             4
# Australia          3
# China              3
# Canada             3
# United Kingdom     3
# Peru               2
# Greece             2
# Belgium            2
# Poland             2
# Netherlands        2
# Indonesia          2
# Croatia            1
# Romania            1
# Estonia            1
# India              1
# South Korea        1
# Spain              1
# Israel             1
# Thailand           1
# Denmark            1
# Slovenia           1
# Russia             1
# Japan              1
# Italy              1
# Norway             1
# New Zealand        1
# Austria            1
# Mexico             1
# Name: Country, dtype: int64

# %%
aug['Country'].value_counts()
# Out:
# United States                 97
# United Kingdom                17
# Australia                     12
# Canada                         9
# France                         7
# India                          6
# Japan                          4
# Sweden                         4
# South Africa                   4
# Brazil                         4
# Germany                        3
# Spain                          3
# Italy                          3
# Mexico                         3
# New Zealand                    3
# Ireland                        2
# Peru                           2
# Poland                         2
# Romania                        2
# Israel                         2
# Vietnam                        2
# Guatemala                      1
# Switzerland                    1
# Malaysia                       1
# Togo                           1
# Bangladesh                     1
# Indonesia                      1
# Venezuela                      1
# ...

# %%
play = pd.read_csv('CSV_files/PLAY_Cleaned.csv')
rh = pd.read_csv('CSV_files/RansomHub_Cleaned.csv')

# %%
play['Country'].value_counts()
# Out:
# United States     197
# Canada             24
# Germany             7
# Sweden              4
# Netherlands         4
# Denmark             3
# United Kingdom      3
# Greece              2
# Luxembourg          2
# Poland              2
# Argentina           1
# Switzerland         1
# Belgium             1
# Australia           1
# Name: Country, dtype: int64

# %%
rh['Country'].value_counts()
# Out:
# United States                 103
# Brazil                         18
# Australia                      16
# Italy                          14
# United Kingdom                 14
# Canada                          8
# Spain                           8
# Germany                         7
# Japan                           5
# South Africa                    4
# Sweden                          4
# Poland                          4
# Turkey                          4
# India                           4
# Romania                         4
# France                          3
# Taiwan                          3
# New Zealand                     3
# Peru                            3
# Malaysia                        2
# Netherlands                     2
# Switzerland                     2
# United Arab Emirates            1
# Austria                         1
# Myanmar                         1
# Serbia                          1
# Russia                          1
# ...
